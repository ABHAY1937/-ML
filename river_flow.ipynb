# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHAY1937/-ML/blob/main/river_flow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Daily River Authority trends for Kidangoor from 01-Jan-1990 to 11-Jul-2022

# %%
kidangoor = pd.read_csv("/content/Kidangoor_full new.csv")
kidangoor
# Out:
#            Dates  Last 10 Year Average (Flow in cumecs)  \
# 0      01-Jan-90                               3.303800
# 1      02-Jan-90                               3.090800
# 2      03-Jan-90                               3.458200
# 3      04-Jan-90                               2.538000
# 4      05-Jan-90                               2.988800
# ...          ...                                    ...
# 11186  02-May-22                              12.165855
# 11187  03-May-22                               7.412327
# 11188  04-May-22                               7.579143
# 11189  05-May-22                              10.682835
# 11190  08-May-22                              29.205803
#
#        Last Year (Flow in cumecs) Current Year (Flow in cumecs) Level (m)
# 0                           1.100                         1.515      0.53
# 1                           1.403                         1.347      0.52
# ...

# %%
kidangoor.shape
# Out:
# (11191, 5)

# %%
kidangoor.dtypes
# Out:
# Dates                                     object
# Last 10 Year Average (Flow in cumecs)    float64
# Last Year (Flow in cumecs)               float64
# Current Year (Flow in cumecs)             object
# Level (m)                                 object
# dtype: object

# %%
kidangoor.isna().sum()
# Out:
# Dates                                    0
# Last 10 Year Average (Flow in cumecs)    0
# Last Year (Flow in cumecs)               0
# Current Year (Flow in cumecs)            0
# Level (m)                                0
# dtype: int64

# %%
kidangoor.corr()
# Out:
# <ipython-input-16-9b50c8aef8ea>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   kidangoor.corr()
#                                        Last 10 Year Average (Flow in cumecs)  \
# Last 10 Year Average (Flow in cumecs)                               1.000000
# Last Year (Flow in cumecs)                                          0.579662
#
#                                        Last Year (Flow in cumecs)
# Last 10 Year Average (Flow in cumecs)                    0.579662
# Last Year (Flow in cumecs)                               1.000000

# %%
sns.heatmap(kidangoor.corr())
# Out:
# <ipython-input-17-276eb547af29>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(kidangoor.corr())
# <Axes: >

# %%
ramam = pd.read_csv("/content/Ramamangalam_full.csv")
ramam
# Out:
#                                                                                                            Daily River Authority trends for Ramamangalam from 01-Jan-1990 to 11-Jul-2022
# Dates       Last 10 Year Average (Flow in cumecs) Last Year (Flow in cumecs) Current Year (Flow in cumecs)                                          Level (m)
# 01-Jan-1990 68.03                                 56                         63                                                                          1.68
# 02-Jan-1990 71.552                                45.54                      74                                                                           1.8
# 03-Jan-1990 66.915                                48.05                      78                                                                          1.84
# 04-Jan-1990 65.515                                61.11                      66.35                                                                       1.79
# ...

# %%
thumpamon = pd.read_csv("/content/Thumpamon_full (1).csv")
thumpamon
# Out:
#                                                                                                            Daily River Authority trends for Thumpamon from 01-Jan-1990 to 11-Jul-2022
# Dates       Last 10 Year Average (Flow in cumecs) Last Year (Flow in cumecs) Current Year (Flow in cumecs)                                          Level (m)
# 01-Jan-1990 5.3911                                1.9                        3.091                                                                       6.19
# 02-Jan-1990 6.0127999999999995                    1.666                      3.321                                                                       6.21
# 03-Jan-1990 6.640199999999999                     1.612                      11.19                                                                       6.49
# 04-Jan-1990 7.442900000000002                     1.35                       4.506                                                                       6.26
# ...
